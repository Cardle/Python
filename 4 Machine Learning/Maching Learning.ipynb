# %% [markdown]
# # Maching Learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mglearn
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 10

# %%
# %matplotlib inline

# %%
iris_dataset = load_iris()
print('keys of iris_dataset:\n{}'.format(iris_dataset.keys()))
# Out:
# keys of iris_dataset:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
print(iris_dataset['DESCR'][:193]+'\n...')
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, pre
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'],random_state=0)
X_train[:10]
# Out:
# array([[5.9, 3. , 4.2, 1.5],
#        [5.8, 2.6, 4. , 1.2],
#        [6.8, 3. , 5.5, 2.1],
#        [4.7, 3.2, 1.3, 0.2],
#        [6.9, 3.1, 5.1, 2.3],
#        [5. , 3.5, 1.6, 0.6],
#        [5.4, 3.7, 1.5, 0.2],
#        [5. , 2. , 3.5, 1. ],
#        [6.5, 3. , 5.5, 1.8],
#        [6.7, 3.3, 5.7, 2.5]])

# %%
y_train[:10]
# Out:
# array([1, 1, 2, 0, 2, 0, 0, 1, 2, 2])

# %%
iris_df = pd.DataFrame(X_train, columns=iris_dataset.feature_names)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.9               3.0                4.2               1.5
# 1                  5.8               2.6                4.0               1.2
# 2                  6.8               3.0                5.5               2.1
# 3                  4.7               3.2                1.3               0.2
# 4                  6.9               3.1                5.1               2.3
# ..                 ...               ...                ...               ...
# 107                4.9               3.1                1.5               0.1
# 108                6.3               2.9                5.6               1.8
# 109                5.8               2.7                4.1               1.0
# 110                7.7               3.8                6.7               2.2
# 111                4.6               3.2                1.4               0.2
#
# [112 rows x 4 columns]

# %%
grr = pd.plotting.scatter_matrix(iris_df, 
                                 c=y_train, 
                                 figsize=(12,12), 
                                 marker='o', 
                                 hist_kwds={'bins':20}, 
                                 s=60, 
                                 alpha=0.8)
                                 #cmap=mglearn.cm3)
grr
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F1E9D387F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB78C5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB0B65C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB494B38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB4C60F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB4ED668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB513BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB5461D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB546208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB593C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB5C5208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB5ED780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB615CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB6452B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB66D828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F1EB695DA0>]],
#       dtype=object)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform')

# %%
X_new = np.array([[5,2.9,1,0.2]])
print('X_new.shape:{}'.format(X_new.shape))
# Out:
# X_new.shape:(1, 4)

# %%
iris_dataset['target_names'][knn.predict(X_new)]
# Out:
# array(['setosa'], dtype='<U10')

# %% [markdown]
# ## 监督学习

# %%
# generate dataset
X, y = mglearn.datasets.make_forge()
# plot dataset
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.legend(["Class 0", "Class 1"], loc=4)
plt.xlabel("First feature")
plt.ylabel("Second feature")
print("X.shape:", X.shape)
# Out:
# X.shape: (26, 2)

# %% [markdown]
# ### 监督学习算法

# %%
data_x = pd.DataFrame(mglearn.datasets.make_forge()[0])
data_y = pd.DataFrame(mglearn.datasets.make_forge()[1])
data = pd.concat([data_x,data_y],axis=1)
data.columns = ['X0','X1','y']
data
# Out:
#            X0        X1  y
# 0    9.963466  4.596765  1
# 1   11.032954 -0.168167  0
# 2   11.541558  5.211161  1
# 3    8.692890  1.543220  0
# 4    8.106227  4.286960  0
# ..        ...       ... ..
# 21   9.500490 -0.264303  0
# 22   8.344688  1.638243  0
# 23   9.501693  1.938246  0
# 24   9.150723  5.498322  1
# 25  11.563957  1.338940  0
#
# [26 rows x 3 columns]
